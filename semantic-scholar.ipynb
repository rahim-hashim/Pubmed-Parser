# %% [markdown]
# # Pubmed Parser
# ### Textual Analysis
#
# __Notebook Description:__ PubmedParser is a Python-based web scraper specifically designed to scrape, parse, and analyze NCBI's online pubmed database (https://www.ncbi.nlm.nih.gov/pubmed). This scraper can be used in a number of ways, one of which is utilized here to performa a textual analysis of specific researchers' abstracts. <br>
# __Notebook Owner:__ Rahim Hashim <br>
# __Contact:__ rh2898@columbia.edu <br>

# %% [markdown]
# ***

# %% [markdown]
# ### Import Libraries
# __Public List:__ os, re, sys, string, datetime, pandas, numpy, tqdm, ntlk, collections, urllib, bs4, unidecode, matplotlib<br>
# __Additional Code:__ Regions
#
# After following the directions for Managing Virtual Environments above, all of the libraries from the public list will be set up. Regions.py included in the directory will provide the rest of the functions used in this codebase.

# %%
# %load_ext autoreload
# %autoreload 2
import os
import re
import sys
import string
import datetime
import pprint
import pandas as pd
import numpy as np
from tqdm.auto import tqdm
import matplotlib.pyplot as plt
from collections import defaultdict, Counter

# if running on google colab, mount google drive
if 'google.colab' in str(get_ipython()): 
  from google.colab import drive
  drive.mount('/content/drive', force_remount=True)
  sys.path.append('/content/drive/MyDrive/Projects/pubmed-parser/Pubmed-Parser') # set to path of notebook

# %% [markdown]
# ***

# %% [markdown]
# ### Assigning Search Term Parameters
#
# First we will assign the search parameters for scraping. In particular, test the key terms you will be searcing for in the database of choice, and then assign it to the SearchParameters.searchTerms attribute.
#
# Here you can use the same logical operators (i.e. AND | OR | NOT) to construct advanced queries in same way that is used in NCBI searches. Examples below:
#
#
# > `search_terms = ['Stefano Fusi']`<br>
# > `search_terms = ['Stefano Fusi AND Nature Neuroscience[Journal]]`
# > `search_terms = ['hippocampus[Title] AND amygdala[Title]]`<br>

# %%
search_terms = ['Stefano Fusi',
								'Daniel Salzman']

# %%
from helper.searchObjects import SearchParameters

parameters = {}
# Database : Specified NCBI database
#   Options = Pubmed [pubmed] | Pubmed Central [PMC] | Unigene [Unigene] | Others [Look Up Key]
parameters['database'] = 'pubmed'
# SearchTerms : PubMed desired search term(s)
parameters['searchTerms'] = search_terms
# searchLimit : Max number of articles for each search term
parameters['searchLimit'] = 100
# StartIndex : The start index for the search (larger for older papers)
parameters['startIndex'] = 0

searchParameters = SearchParameters(parameters)

# %% [markdown]
# ***
# ### Generating List of Database Search Result URLs
#
# Using the [NCBI Entrez API](https://www.ncbi.nlm.nih.gov/books/NBK25499/#chapter4.ESearch), eSearchLinkGenerator generates an XML containing the list of URLs for the articles returned by searchParameters.searchTerms attribute, up until the amount of articles specified by searchLimit. resultsList generates a nested list of all article URLs.
#
# As of December 2021, **NCBI requires an API key** in order to make more than 3 requests per second to Entrez. Users can obtain an API key now from the Settings page of their NCBI account (to create an account, visit http://www.ncbi.nlm.nih.gov/account/). After creating the key, users should include it in each E-utility request by assigning it to the new api_key parameter. See: [Entrez Documentation](https://www.ncbi.nlm.nih.gov/books/NBK25497/) for more information.
#
# Once you've generated an API key, create a new file named .env and in the first line, assign a variable<br>
# > `NCBI_API_KEY = '<>'`

# %%
from helper.entrezParser import eSearchLinkGenerator, PMID_ListGenerator
from dotenv import load_dotenv
load_dotenv()

NCBI_API_KEY = os.getenv('NCBI_API_KEY') # set in .env file

def entrezSearch(searchParameters):
  '''
  entrezSearch generates resultsList, which is
  a list of all article URLs for each search term

  Args:
    searchParameters (SearchParameters): SearchParameters object
    containing search parameters assigned above

  Returns:
    resultsList (list): list of all article URLs for each search term
  '''
  eSearchCore = 'http://eutils.ncbi.nlm.nih.gov/entrez//eutils/esearch.fcgi/?db=&term=&retmax=&retstart='
  api = NCBI_API_KEY
  eSearchLinkList = eSearchLinkGenerator(eSearchCore, searchParameters, api)
  resultsList = PMID_ListGenerator(eSearchLinkList)
  return resultsList

resultsList = entrezSearch(searchParameters)
# Out:
# Generating Entrez XML...
#    [Stefano Fusi] complete
#    [Daniel Salzman] complete
#
# Generating list of PMIDs...
#   Stefano Fusi: 67 results
#   Daniel Salzman: 33 results

# %% [markdown]
# ***
# ### Parsing Data
#
# For each searchTerm provided to searchParameters, dataParser will take each of the article URLs and parse the specified information, inserting it into a multi-nested dictionary queriesHash to be further analyzed.

# %%
from helper.linksParser import linksParser

def dataParser(resultsList):
  """
  dataParser creates a multi-nested dictionary
  containing all article data for each search term

  Args:
    resultsList (list): list of all article URLs for each search term
  
  Returns:
    data (dict): multi-nested dictionary containing all article data for each search term
  """
  print('\nParsing info for search terms...')
  queriesHash = defaultdict(lambda: defaultdict(list)) # primary key = pubmed query
  for a_index, termLinks in enumerate(resultsList):
    query = searchParameters.searchTerms[a_index]
    searchesHash = linksParser(termLinks, searchParameters, query)
    queriesHash[query] = searchesHash  
  return queriesHash

searchesHash = dataParser(resultsList)
# Out:
# Parsing info for search terms...
#   Stefano Fusi
#   0%|          | 0/67 [00:00<?, ?it/s]
#   Daniel Salzman
#   0%|          | 0/33 [00:00<?, ?it/s]

# %% [markdown]
# ***
# ### Semantic Scholar
#
# [Semantic Scholar](https://www.semanticscholar.org/) is an incredible tool built by the Allen Institute which provides free, AI-driven search and discovery tools, and open resources for the global research community. They've built a useful [API](https://www.semanticscholar.org/product/api#Documentation) which we will utilize to generate additional data (i.e. citation count) on each of the papers found for each search term which was not available through Entrez.

# %%
from semantic_scholar_query import semantic_scholar_search
searchesHash = semantic_scholar_search(searchesHash, verbose=True)
# Out:
# Query: Stefano Fusi
#   ('Title: Perirhinal Cortex Learns A Predictive Map of The Task Environment '
#    '(2023/04/10)')
# 	'PMID: 36993645'
# 	'Citation Count: 0'
# 	'Semantic Scholar Citation Count: 0'
#   ('Title: Abstract representations emerge naturally in neural networks trained '
#    'to perform multiple tasks (2023/02/23)')
# 	'PMID: 36823136'
# 	'Citation Count: 10'
# 	'Semantic Scholar Citation Count: 0'
#   'Title: Face familiarity detection with complex synapses (2022/12/22)'
# 	'PMID: 36636347'
# 	'Citation Count: 2'
# 	'Semantic Scholar Citation Count: 0'
#   'Title: The geometry of cortical representations of touch in rodents (2023)'
# 	'PMID: 36624277'
# 	'Citation Count: 15'
# 	'Semantic Scholar Citation Count: 1'
#   ('Title: The implications of categorical and category-free mixed selectivity '
#    'on representational geometries (2022)')
# 	'PMID: 36332415'
# 	'Citation Count: 8'
# 	'Semantic Scholar Citation Count: 0'
#   ('Title: Adolescent thalamic inhibition leads to long-lasting impairments in '
#    'prefrontal cortex function (2022)')
# 	'PMID: 35590075'
# 	'Citation Count: 8'
# 	'Semantic Scholar Citation Count: 0'
#   ('Title: Signatures of rapid plasticity in hippocampal CA1 representations '
#    'during novel experiences (2022/06/15)')
# 	'PMID: 35447088'
# 	'Citation Count: 23'
# 	'Semantic Scholar Citation Count: 0'
#   ('Title: Place cells may simply be memory cells: Memory compression leads to '
#    'spatial tuning and history dependence (2021/12/21)')
# 	'PMID: 34916282'
# 	'Citation Count: 20'
# 	'Semantic Scholar Citation Count: 0'
#   ('Title: Sensorimotor strategies and neuronal representations for shape '
#    'discrimination (2021/07/21)')
# 	'PMID: 34133944'
# 	'Citation Count: 15'
# 	'Semantic Scholar Citation Count: 0'
#   'Title: Perceiving ensemble statistics of novel image sets (2021)'
# 	'PMID: 33420715'
# 	'Citation Count: 5'
# 	'Semantic Scholar Citation Count: 0'
#   ('Title: Coding of social novelty in the hippocampal CA2 region and its '
#    'disruption and rescue in a 22q11.2 microdeletion mouse model (2020)')
# 	'PMID: 33077947'
# 	'Citation Count: 46'
# 	'Semantic Scholar Citation Count: 2'
#   ('Title: The Geometry of Abstraction in the Hippocampus and Prefrontal Cortex '
#    '(2020/11/12)')
# 	'PMID: 33058757'
# 	'Citation Count: 153'
# 	'Semantic Scholar Citation Count: 20'
#   ('Title: Surgical Outcomes of Mastectomy with Immediate Autologous '
#    'Reconstruction Followed by Radiation (2021)')
# 	'PMID: 32974699'
# 	'Citation Count: 4'
# 	'Semantic Scholar Citation Count: 0'
#   ('Title: Low-dimensional dynamics for working memory and time encoding '
#    '(2020/09/15)')
# 	'PMID: 32859756'
# 	'Citation Count: 84'
# 	'Semantic Scholar Citation Count: 2'
#   ('Title: Flexible recruitment of memory-based choice representations by the '
#    'human medial frontal cortex (2020/06/26)')
# 	'PMID: 32586990'
# 	'Citation Count: 53'
# 	'Semantic Scholar Citation Count: 1'
#   'Title: A Distributed Neural Code in the Dentate Gyrus and in CA1 (2020/08/19)'
# 	'PMID: 32521223'
# 	'Citation Count: 79'
# 	'Semantic Scholar Citation Count: 3'
#   ('Title: Hippocampal Network Reorganization Underlies the Formation of a '
#    'Temporal Association Memory (2020/07/22)')
# 	'PMID: 32392472'
# 	'Citation Count: 50'
# 	'Semantic Scholar Citation Count: 1'
#   ('Title: Does walking the day of total hip arthroplasty speed up functional '
#    'independence? A non-randomized controlled study (2020/04/24)')
# 	'PMID: 32346488'
# 	'Citation Count: 4'
# 	'Semantic Scholar Citation Count: 0'
#   ('Title: Context-dependent representations of objects and space in the primate '
#    'hippocampus during virtual navigation (2020)')
# 	'PMID: 31873285'
# 	'Citation Count: 56'
# 	'Semantic Scholar Citation Count: 2'
#   ('Title: Deviation from the matching law reflects an optimal strategy '
#    'involving learning over multiple timescales (2019/04/01)')
# 	'PMID: 30931937'
# 	'Citation Count: 30'
# 	'Semantic Scholar Citation Count: 2'
#   ('Title: Neural Classifiers with Limited Connectivity and Recurrent Readouts '
#    '(2018/11/14)')
# 	'PMID: 30249794'
# 	'Citation Count: 4'
# 	'Semantic Scholar Citation Count: 1'
#   ('Title: Three-dimensional Analysis of How Radiation Affects Deep Inferior '
#    'Epigastric Perforator (DIEP) Flap Volume, Projection, and Position in Breast '
#    'Cancer Reconstruction (2018)')
# 	'PMID: 29794501'
# 	'Citation Count: 9'
# 	'Semantic Scholar Citation Count: 1'
#   ('Title: Hebbian Learning in a Random Network Captures Selectivity Properties '
#    'of the Prefrontal Cortex (2017/11/08)')
# 	'PMID: 28986463'
# 	'Citation Count: 37'
# 	'Semantic Scholar Citation Count: 1'
#   'Title: Computational principles of synaptic memory consolidation (2016)'
# 	'PMID: 27694992'
# 	'Citation Count: 160'
# 	'Semantic Scholar Citation Count: 12'
#   'Title: Energy-Efficient Neuromorphic Classifiers (2016)'
# 	'PMID: 27557100'
# 	'Citation Count: 32'
# 	'Semantic Scholar Citation Count: 0'
#   'Title: Why neurons mix: high dimensionality for higher cognition (2016)'
# 	'PMID: 26851755'
# 	'Citation Count: 466'
# 	'Semantic Scholar Citation Count: 34'
#   ('Title: Hippocampal-prefrontal input supports spatial encoding in working '
#    'memory (2015/06/18)')
# 	'PMID: 26053122'
# 	'Citation Count: 504'
# 	'Semantic Scholar Citation Count: 29'
#   'Title: Blogging to bolster your plastic surgery career (2015)'
# 	'PMID: 25647702'
# 	'Citation Count: 7'
# 	'Semantic Scholar Citation Count: 0'
#   ('Title: Ubersense: using a free video analysis app to evaluate and improve '
#    'microsurgical skills (2014)')
# 	'PMID: 25068366'
# 	'Citation Count: 7'
# 	'Semantic Scholar Citation Count: 0'
#   "Title: Don't sleep on your DIEP (2014)"
# 	'PMID: 24776594'
# 	'Citation Count: 0'
# 	'Semantic Scholar Citation Count: 0'
#   ('Title: Simulated surgery and cutting guides enhance spatial positioning in '
#    'free fibular mandibular reconstruction (2015)')
# 	'PMID: 24470389'
# 	'Citation Count: 54'
# 	'Semantic Scholar Citation Count: 1'
#   ('Title: Adult neurogenesis in the mammalian hippocampus: why the dentate '
#    'gyrus? (2013/11/19)')
# 	'PMID: 24255101'
# 	'Citation Count: 121'
# 	'Semantic Scholar Citation Count: 7'
#   'Title: Dynamical regimes in neural network models of matching behavior (2013)'
# 	'PMID: 24047324'
# 	'Citation Count: 14'
# 	'Semantic Scholar Citation Count: 0'
#   ('Title: Efficient partitioning of memory systems and its importance for '
#    'memory consolidation (2013)')
# 	'PMID: 23935470'
# 	'Citation Count: 63'
# 	'Semantic Scholar Citation Count: 4'
#   ('Title: Radiation therapy and expander-implant breast reconstruction: an '
#    'analysis of timing and comparison of complications (2013)')
# 	'PMID: 23788143'
# 	'Citation Count: 54'
# 	'Semantic Scholar Citation Count: 0'
#   ('Title: The importance of mixed selectivity in complex cognitive tasks '
#    '(2013/05/30)')
# 	'PMID: 23685452'
# 	'Citation Count: 1169'
# 	'Semantic Scholar Citation Count: 76'
#   'Title: Synaptic encoding of temporal contiguity (2013/04/12)'
# 	'PMID: 23641210'
# 	'Citation Count: 13'
# 	'Semantic Scholar Citation Count: 2'
#   'Title: Limber neurons for a nimble mind (2013/04/24)'
# 	'PMID: 23622059'
# 	'Citation Count: 17'
# 	'Semantic Scholar Citation Count: 1'
#   ('Title: The sparseness of mixed selectivity neurons controls the '
#    'generalization-discrimination trade-off (2013/02/27)')
# 	'PMID: 23447596'
# 	'Citation Count: 169'
# 	'Semantic Scholar Citation Count: 15'
#   ('Title: Does the left hand know what the right hand is doing? What plastic '
#    'surgeons need to know about radiation therapy techniques (2012)')
# 	'PMID: 23096658'
# 	'Citation Count: 0'
# 	'Semantic Scholar Citation Count: 0'
#   ('Title: Learning selective top-down control enhances performance in a visual '
#    'categorization task (2012)')
# 	'PMID: 22972954'
# 	'Citation Count: 9'
# 	'Semantic Scholar Citation Count: 0'
#   ('Title: Immediate nipple reconstruction utilizing the DIEP flap in '
#    'areola-sparing mastectomy (2013)')
# 	'PMID: 22903381'
# 	'Citation Count: 16'
# 	'Semantic Scholar Citation Count: 0'
#   ('Title: Venous thromboembolism risk factors in breast cancer patients '
#    'undergoing deep inferior epigastric perforator flap reconstruction (2012)')
# 	'PMID: 22437263'
# 	'Citation Count: 2'
# 	'Semantic Scholar Citation Count: 0'
#   ('Title: Internal representation of task rules by recurrent dynamics: the '
#    'importance of the diversity of neural responses (2010/10/04)')
# 	'PMID: 21048899'
# 	'Citation Count: 172'
# 	'Semantic Scholar Citation Count: 5'
#   ('Title: Emotion, cognition, and mental state representation in amygdala and '
#    'prefrontal cortex (2010)')
# 	'PMID: 20331363'
# 	'Citation Count: 476'
# 	'Semantic Scholar Citation Count: 17'
#   ('Title: Attractor concretion as a mechanism for the formation of context '
#    'representations (2010)')
# 	'PMID: 20100580'
# 	'Citation Count: 45'
# 	'Semantic Scholar Citation Count: 4'
#   'Title: Learning flexible sensori-motor mappings in a complex network (2009)'
# 	'PMID: 19153762'
# 	'Citation Count: 19'
# 	'Semantic Scholar Citation Count: 0'
#   ('Title: The response of cortical neurons to in vivo-like input current: '
#    'theory and experiment: II. Time-varying and spatially distributed inputs '
#    '(2008)')
# 	'PMID: 19011920'
# 	'Citation Count: 28'
# 	'Semantic Scholar Citation Count: 1'
#   ('Title: The response of cortical neurons to in vivo-like input current: '
#    'theory and experiment : I. Noisy inputs with stationary statistics (2008)')
# 	'PMID: 18985378'
# 	'Citation Count: 61'
# 	'Semantic Scholar Citation Count: 3'
#   ('Title: Long memory lifetimes require complex synapses and limited sparseness '
#    '(2007/11/30)')
# 	'PMID: 18946529'
# 	'Citation Count: 40'
# 	'Semantic Scholar Citation Count: 5'
#   'Title: Neuroscience. A quiescent working memory (2008/03/14)'
# 	'PMID: 18339929'
# 	'Citation Count: 10'
# 	'Semantic Scholar Citation Count: 2'
#   ('Title: The dynamical response properties of neocortical neurons to '
#    'temporally modulated noisy inputs in vitro (2008)')
# 	'PMID: 18263893'
# 	'Citation Count: 108'
# 	'Semantic Scholar Citation Count: 12'
#   ('Title: Learning real-world stimuli in a neural network with spike-driven '
#    'synaptic dynamics (2007)')
# 	'PMID: 17883345'
# 	'Citation Count: 337'
# 	'Semantic Scholar Citation Count: 54'
#   ('Title: A neural circuit model of flexible sensorimotor mapping: learning and '
#    'forgetting on multiple timescales (2007/04/19)')
# 	'PMID: 17442251'
# 	'Citation Count: 171'
# 	'Semantic Scholar Citation Count: 11'
#   'Title: Limits on the memory storage capacity of bounded synapses (2007)'
# 	'PMID: 17351638'
# 	'Citation Count: 203'
# 	'Semantic Scholar Citation Count: 12'
#   ('Title: Eluding oblivion with smart stochastic selection of synaptic updates '
#    '(2006)')
# 	'PMID: 16822044'
# 	'Citation Count: 26'
# 	'Semantic Scholar Citation Count: 1'
#   ('Title: Multiple time scales of temporal response in pyramidal and fast '
#    'spiking cortical neurons (2006)')
# 	'PMID: 16807345'
# 	'Citation Count: 114'
# 	'Semantic Scholar Citation Count: 9'
#   ('Title: Learning to attend: modeling the shaping of selectivity in '
#    'infero-temporal cortex in a categorization task (2006)')
# 	'PMID: 16555071'
# 	'Citation Count: 26'
# 	'Semantic Scholar Citation Count: 3'
#   ('Title: Learning only when necessary: better memories of correlated patterns '
#    'in networks with bounded synapses (2005)')
# 	'PMID: 16105220'
# 	'Citation Count: 46'
# 	'Semantic Scholar Citation Count: 6'
#   ('Title: Convergence of stochastic learning in perceptrons with binary '
#    'synapses (2005)')
# 	'PMID: 16089765'
# 	'Citation Count: 57'
# 	'Semantic Scholar Citation Count: 6'
#   'Title: Cascade models of synaptically stored memories (2005/02/17)'
# 	'PMID: 15721245'
# 	'Citation Count: 507'
# 	'Semantic Scholar Citation Count: 36'
#   ('Title: Minimal models of adapted neuronal response to in vivo-like input '
#    'currents (2004)')
# 	'PMID: 15333209'
# 	'Citation Count: 137'
# 	'Semantic Scholar Citation Count: 8'
#   ('Title: Modelling the formation of working memory with networks of '
#    'integrate-and-fire neurons connected by plastic synapses (2003)')
# 	'PMID: 15242673'
# 	'Citation Count: 81'
# 	'Semantic Scholar Citation Count: 8'
#   ('Title: Climbing neuronal activity as an event-based cortical representation '
#    'of time (2004/03/31)')
# 	'PMID: 15056709'
# 	'Citation Count: 151'
# 	'Semantic Scholar Citation Count: 12'
#   ('Title: Neocortical pyramidal cells respond as integrate-and-fire neurons to '
#    'in vivo-like input currents (2003)')
# 	'PMID: 12750422'
# 	'Citation Count: 311'
# 	'Semantic Scholar Citation Count: 26'
#   ('Title: Event-driven simulation of spiking neurons with stochastic dynamics '
#    '(2003)')
# 	'PMID: 12689388'
# 	'Citation Count: 63'
# 	'Semantic Scholar Citation Count: 9'
#   ('Title: Hebbian spike-driven synaptic plasticity for learning patterns of '
#    'mean firing rates (2002)')
# 	'PMID: 12461635'
# 	'Citation Count: 143'
# 	'Semantic Scholar Citation Count: 9'
# Query: Daniel Salzman
#   ('Title: Visuospatial information foraging describes search behavior in '
#    'learning latent environmental features (2023/01/20)')
# 	'PMID: 36670132'
# 	'Citation Count: 1'
# 	'Semantic Scholar Citation Count: 0'
#   ('Title: Prelimbic cortex drives discrimination of non-aversion via amygdala '
#    'somatostatin interneurons (2022/07/20)')
# 	'PMID: 35397211'
# 	'Citation Count: 6'
# 	'Semantic Scholar Citation Count: 0'
#   ('Title: Partitioning variability in animal behavioral videos using '
#    'semi-supervised variational autoencoders (2021/09/22)')
# 	'PMID: 34550974'
# 	'Citation Count: 19'
# 	'Semantic Scholar Citation Count: 2'
#   ('Title: The Geometry of Abstraction in the Hippocampus and Prefrontal Cortex '
#    '(2020/11/12)')
# 	'PMID: 33058757'
# 	'Citation Count: 153'
# 	'Semantic Scholar Citation Count: 20'
#   ('Title: Low-dimensional dynamics for working memory and time encoding '
#    '(2020/09/15)')
# 	'PMID: 32859756'
# 	'Citation Count: 84'
# 	'Semantic Scholar Citation Count: 2'
#   ('Title: The contribution of nonhuman primate research to the understanding of '
#    'emotion and cognition and its clinical relevance (2019/12/26)')
# 	'PMID: 31871162'
# 	'Citation Count: 19'
# 	'Semantic Scholar Citation Count: 0'
#   'Title: The coding of valence and identity in the mammalian taste system (2018)'
# 	'PMID: 29849148'
# 	'Citation Count: 135'
# 	'Semantic Scholar Citation Count: 13'
#   'Title: Basolateral amygdala circuitry in positive and negative valence (2018)'
# 	'PMID: 29525574'
# 	'Citation Count: 64'
# 	'Semantic Scholar Citation Count: 3'
#   ('Title: Shared neural coding for social hierarchy and reward value in primate '
#    'amygdala (2018)')
# 	'PMID: 29459764'
# 	'Citation Count: 72'
# 	'Semantic Scholar Citation Count: 4'
#   ('Title: Distinct Roles for the Amygdala and Orbitofrontal Cortex in '
#    'Representing the Relative Amount of Expected Reward (2017/07/05)')
# 	'PMID: 28683271'
# 	'Citation Count: 62'
# 	'Semantic Scholar Citation Count: 3'
#   ('Title: Reward expectation differentially modulates attentional behavior and '
#    'activity in visual area V4 (2015)')
# 	'PMID: 26479590'
# 	'Citation Count: 62'
# 	'Semantic Scholar Citation Count: 4'
#   ('Title: Manipulating neural activity in physiologically classified neurons: '
#    'triumphs and challenges (2015/09/19)')
# 	'PMID: 26240431'
# 	'Citation Count: 11'
# 	'Semantic Scholar Citation Count: 1'
#   'Title: Understanding the brain by controlling neural activity (2015/09/19)'
# 	'PMID: 26240417'
# 	'Citation Count: 18'
# 	'Semantic Scholar Citation Count: 0'
#   ('Title: Neural Representations of Unconditioned Stimuli in Basolateral '
#    'Amygdala Mediate Innate and Learned Responses (2015/07/02)')
# 	'PMID: 26140594'
# 	'Citation Count: 178'
# 	'Semantic Scholar Citation Count: 16'
#   'Title: Task-dependent spatial selectivity in the primate amygdala (2014/12/03)'
# 	'PMID: 25471563'
# 	'Citation Count: 14'
# 	'Semantic Scholar Citation Count: 0'
#   ('Title: Amygdala neural activity reflects spatial attention towards stimuli '
#    'promising reward or threatening punishment (2014/10/30)')
# 	'PMID: 25358090'
# 	'Citation Count: 53'
# 	'Semantic Scholar Citation Count: 1'
#   ('Title: The amygdala and basal forebrain as a pathway for motivationally '
#    'guided attention (2014/10/08)')
# 	'PMID: 25297102'
# 	'Citation Count: 53'
# 	'Semantic Scholar Citation Count: 1'
#   'Title: The primate amygdala combines information about space and value (2013)'
# 	'PMID: 23377126'
# 	'Citation Count: 112'
# 	'Semantic Scholar Citation Count: 3'
#   ('Title: Functional circuits and anatomical distribution of response '
#    'properties in the primate amygdala (2013/01/09)')
# 	'PMID: 23303950'
# 	'Citation Count: 67'
# 	'Semantic Scholar Citation Count: 6'
#   ('Title: Complexity and competition in appetitive and aversive neural circuits '
#    '(2012/11/26)')
# 	'PMID: 23189037'
# 	'Citation Count: 37'
# 	'Semantic Scholar Citation Count: 2'
#   ('Title: Representations of appetitive and aversive information in the primate '
#    'orbitofrontal cortex (2011)')
# 	'PMID: 22145876'
# 	'Citation Count: 57'
# 	'Semantic Scholar Citation Count: 2'
#   ('Title: Different time courses for learning-related changes in amygdala and '
#    'orbitofrontal cortex (2011/09/22)')
# 	'PMID: 21943608'
# 	'Citation Count: 119'
# 	'Semantic Scholar Citation Count: 10'
#   ('Title: Emotion, cognition, and mental state representation in amygdala and '
#    'prefrontal cortex (2010)')
# 	'PMID: 20331363'
# 	'Citation Count: 476'
# 	'Semantic Scholar Citation Count: 17'
#   'Title: Re-valuing the amygdala (2010)'
# 	'PMID: 20299204'
# 	'Citation Count: 306'
# 	'Semantic Scholar Citation Count: 15'
#   ('Title: Attractor concretion as a mechanism for the formation of context '
#    'representations (2010)')
# 	'PMID: 20100580'
# 	'Citation Count: 45'
# 	'Semantic Scholar Citation Count: 4'
#   ('Title: The convergence of information about rewarding and aversive stimuli '
#    'in single neurons (2009/09/16)')
# 	'PMID: 19759296'
# 	'Citation Count: 181'
# 	'Semantic Scholar Citation Count: 19'
#   'Title: The rhythms of learning (2009)'
# 	'PMID: 19471263'
# 	'Citation Count: 11'
# 	'Semantic Scholar Citation Count: 0'
#   'Title: Moment-to-moment tracking of state value in the amygdala (2008/10/01)'
# 	'PMID: 18829960'
# 	'Citation Count: 205'
# 	'Semantic Scholar Citation Count: 10'
#   ('Title: Noncholinergic neurons in the basal forebrain: often neglected but '
#    'motivationally salient (2008/07/10)')
# 	'PMID: 18614024'
# 	'Citation Count: 8'
# 	'Semantic Scholar Citation Count: 0'
#   ('Title: Expectation modulates neural responses to pleasant and aversive '
#    'stimuli in primate amygdala (2007/09/20)')
# 	'PMID: 17880899'
# 	'Citation Count: 342'
# 	'Semantic Scholar Citation Count: 23'
#   'Title: Flexible neural representations of value in the primate brain (2007)'
# 	'PMID: 17872400'
# 	'Citation Count: 65'
# 	'Semantic Scholar Citation Count: 1'
#   ('Title: The primate amygdala represents the positive and negative value of '
#    'visual stimuli during learning (2006/02/16)')
# 	'PMID: 16482160'
# 	'Citation Count: 879'
# 	'Semantic Scholar Citation Count: 55'
#   ('Title: Beetles, boxes and brain cells: neural mechanisms underlying '
#    'valuation and learning (2005)')
# 	'PMID: 16271457'
# 	'Citation Count: 22'
# 	'Semantic Scholar Citation Count: 0'

# %%
from helper.construct_dataframe import construct_dataframe

authors_df = construct_dataframe(searchesHash)
authors_df
# Out:
# Constructing dataframe...
#                    author      PMID  articleCount
# 0             David G Lee  36993645             0  \
# 1    Caroline A McLachlan  36993645             0
# 2          Ramon Nogueira  36993645             0
# 3              Osung Kwon  36993645             0
# 4            Alanna Carey  36993645             0
# ..                    ...       ...           ...
# 457       Sara E Morrison  16482160            31
# 458      C Daniel Salzman  16482160            31
# 459      C Daniel Salzman  16271457            32
# 460       Marina A Belova  16271457            32
# 461        Joseph J Paton  16271457            32
#
#                                          article_title
# 0    Perirhinal Cortex Learns A Predictive Map of T...  \
# 1    Perirhinal Cortex Learns A Predictive Map of T...
# 2    Perirhinal Cortex Learns A Predictive Map of T...
# 3    Perirhinal Cortex Learns A Predictive Map of T...
# 4    Perirhinal Cortex Learns A Predictive Map of T...
# ..                                                 ...
# 457  The primate amygdala represents the positive a...
# 458  The primate amygdala represents the positive a...
# 459  Beetles, boxes and brain cells: neural mechani...
# 460  Beetles, boxes and brain cells: neural mechani...
# 461  Beetles, boxes and brain cells: neural mechani...
#
#                                  journal_title            publisher
# 0    bioRxiv : the preprint server for biology              bioRxiv  \
# 1    bioRxiv : the preprint server for biology              bioRxiv
# 2    bioRxiv : the preprint server for biology              bioRxiv
# 3    bioRxiv : the preprint server for biology              bioRxiv
# 4    bioRxiv : the preprint server for biology              bioRxiv
# ..                                         ...                  ...
# 457                                     Nature               Nature
# 458                                     Nature               Nature
# 459            Current opinion in neurobiology  Curr Opin Neurobiol
# 460            Current opinion in neurobiology  Curr Opin Neurobiol
# 461            Current opinion in neurobiology  Curr Opin Neurobiol
#
#     publication_date                                 doi
# 0         2023/04/10   doi.org/10.1101/2023.03.17.532214  \
# 1         2023/04/10   doi.org/10.1101/2023.03.17.532214
# 2         2023/04/10   doi.org/10.1101/2023.03.17.532214
# 3         2023/04/10   doi.org/10.1101/2023.03.17.532214
# 4         2023/04/10   doi.org/10.1101/2023.03.17.532214
# ..               ...                                 ...
# 457       2006/02/16         doi.org/10.1038/nature04490
# 458       2006/02/16         doi.org/10.1038/nature04490
# 459             2005  doi.org/10.1016/j.conb.2005.10.016
# 460             2005  doi.org/10.1016/j.conb.2005.10.016
# 461             2005  doi.org/10.1016/j.conb.2005.10.016
#
#                                               abstract
# 0    Goal-directed tasks involve acquiring an inter...  \
# 1    Goal-directed tasks involve acquiring an inter...
# 2    Goal-directed tasks involve acquiring an inter...
# 3    Goal-directed tasks involve acquiring an inter...
# 4    Goal-directed tasks involve acquiring an inter...
# ..                                                 ...
# 457  Visual stimuli can acquire positive or negativ...
# 458  Visual stimuli can acquire positive or negativ...
# 459  Sensory cues in the environment can predict th...
# 460  Sensory cues in the environment can predict th...
# 461  Sensory cues in the environment can predict th...
#
#                                    author_institutions  citation_count
# 0                                                   []               0  \
# 1                                                   []               0
# 2                                                   []               0
# 3                                                   []               0
# 4                                                   []               0
# ..                                                 ...             ...
# 457  [Center for Neurobiology and Behavior, Columbi...             879
# 458  [Center for Neurobiology and Behavior, Columbi...             879
# 459  [Center for Neurobiology and Behavior, Departm...              22
# 460  [Center for Neurobiology and Behavior, Departm...              22
# 461  [Center for Neurobiology and Behavior, Departm...              22
#
#      semantic_scholar_citation_count
# 0                                  0  \
# 1                                  0
# 2                                  0
# 3                                  0
# 4                                  0
# ..                               ...
# 457                               55
# 458                               55
# 459                                0
# 460                                0
# 461                                0
#
#                                          collaborators keywords
# 0    [Caroline A McLachlan, Ramon Nogueira, Osung K...      NaN
# 1    [David G Lee, Ramon Nogueira, Osung Kwon, Alan...      NaN
# 2    [David G Lee, Caroline A McLachlan, Osung Kwon...      NaN
# 3    [David G Lee, Caroline A McLachlan, Ramon Nogu...      NaN
# 4    [David G Lee, Caroline A McLachlan, Ramon Nogu...      NaN
# ..                                                 ...      ...
# 457  [Joseph J Paton, Marina A Belova, C Daniel Sal...      NaN
# 458  [Joseph J Paton, Marina A Belova, Sara E Morri...      NaN
# 459                  [Marina A Belova, Joseph J Paton]      NaN
# 460                 [C Daniel Salzman, Joseph J Paton]      NaN
# 461                [C Daniel Salzman, Marina A Belova]      NaN
#
# [462 rows x 14 columns]

# %% [markdown]
# ***
# ### Abstract Word Count
#
# A simple analysis will be to find the most commonly-used words in each query.
#
# First, remove all the stop words from the abstracts. As defined by the [nltk documentation](https://pythonspot.com/nltk-stop-words/):
#
# >Stop words are common words like ‘the’, ‘and’, ‘I’, etc. that are very frequent in text, and so don’t convey insights into the specific topic of a document. We can remove these stop words from the text in a given corpus to clean up the data, and identify words that are more rare and potentially more relevant to what we’re interested in.
#
# Next, all punctuation, digits, and unncessary characters are removed.
#
# Lastly, each word will be lemmatized, which is defined by [Stanford's NLP group](https://nlp.stanford.edu/IR-book/html/htmledition/stemming-and-lemmatization-1.html) as:
#
# > Removing inflectional endings only and to return the base or dictionary form of a word, which is known as the lemma.
#
# For example, in English, the verb 'to walk' may appear as 'walk', 'walked', 'walks' or 'walking'. The base form, 'walk', that one might look up in a dictionary, is called the lemma for the word.
#
# This program uses [WordNet](https://wordnet.princeton.edu/) which is a large, freely and publicly available lexical database for the English language.

# %%
from helper.wordCount import lemming_count
lemming_count(searchesHash, top_n_words=20)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/rahimhashim/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/rahimhashim/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/rahimhashim/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw to /Users/rahimhashim/nltk_data...
# [nltk_data]   Package omw is already up-to-date!
# Stefano Fusi ['neuron', 'memory', 'neural', 'model', 'synaptic', 'task', 'learning', 'activity', 'network', 'number', 'time', 'synapsis', 'response', 'state', 'representation', 'selectivity', 'show', 'input', 'variable', 'reconstruction']
# Daniel Salzman ['stimulus', 'amygdala', 'neural', 'neuron', 'aversive', 'reward', 'information', 'value', 'response', 'spatial', 'learning', 'brain', 'process', 'attention', 'different', 'ofc', 'state', 'monkey', 'representation', 'sensory']

# %% [markdown]
# ***
# ### Year-by-Year Analysis
#
# The first analysis we'll be performing is year-by-year lexicon frequency. In the example queries provided above, we introduced two authors (Salzman CD, Fusi S) and captured all meta-info (title, journal, date published, etc), and importantly all of the abstracts for each of the author's articles.
#
# In pre-processing we'll __separate stop words__, defined by [NLTK](https://www.nltk.org/book/ch02.html) as: *high-frequency words like 'the', 'to' and 'also' that we sometimes want to filter out of a document before further processing. Stopwords usually have little lexical content, and their presence in a text fails to distinguish it from other texts.*
#
# The data will still be preserved in yearsHash\[year\]\['stopWords'\] if you're interested in analyzing something like self- vs. other-referential pronoun usage.

# %%
from helper.yearExaminer import yearExaminer
yearsHash = yearExaminer(searchesHash)
# Out:
# [   ['2002', 0.875],
#     ['2003', 0.639269406392694],
#     ['2004', 0.7076023391812866],
#     ['2005', 0.6471816283924844],
#     ['2006', 0.6086105675146771],
#     ['2007', 0.5819209039548022],
#     ['2008', 0.5526770293609672],
#     ['2009', 0.6283524904214559],
#     ['2010', 0.3713527851458886],
#     ['2011', 0.6042780748663101],
#     ['2012', 0.6736401673640168],
#     ['2013', 0.5221518987341772],
#     ['2014', 0.5025773195876289],
#     ['2015', 0.6117103235747303],
#     ['2016', 0.7366666666666667],
#     ['2017', 0.5787878787878787],
#     ['2018', 0.5463768115942029],
#     ['2019', 0.726457399103139],
#     ['2020', 0.43273350471293914],
#     ['2021', 0.5798561151079137],
#     ['2022', 0.647982062780269],
#     ['2023', 0.6354679802955665]]
